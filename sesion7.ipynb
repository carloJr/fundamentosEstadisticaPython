# %%
import scipy.stats
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

# %%
df = pd.read_csv('bicicletas-compartidas.csv')
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %%
y = df['bicis-compartidas']
fig, ax =plt.subplots()
ax.boxplot(x = y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x189c74e7d90>,
#   <matplotlib.lines.Line2D at 0x189c74fc130>],
#  'caps': [<matplotlib.lines.Line2D at 0x189c74fc490>,
#   <matplotlib.lines.Line2D at 0x189c74fc7f0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x189c74e7a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x189c74fcb50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x189c74fce50>],
#  'means': []}

# %%
sns.boxplot(x ='cuartil-ano', y ='bicis-compartidas', data = df)

# %%
fig, ax =plt.subplots()
ax.scatter(df['viento'], df['bicis-compartidas'], alpha =0.03)
ax.set_title('Distribucion conjunta de viento y bicis compartidas')
ax.set_xlabel('Viento')
ax.set_ylabel('Bicis compartidas')
# Out:
# Text(0, 0.5, 'Bicis compartidas')
