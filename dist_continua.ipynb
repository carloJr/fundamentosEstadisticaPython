# %%
import scipy.stats
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

from scipy.stats import binom, norm

# %%
n = 10000

x = list(range(0,n+1,1))
y =  list([])

for i in x:
    # y.append(binom.pmf(i, p=0.3,n=n)) -->probability mass function(funcion de probabilidad)
    y.append(binom.cdf(i, p=0.3,n=n))# probabilidad acumulada

fig, ax = plt.subplots()

ax.plot(x,y)
ax.set_title('Probabilidad continua')
# Out:
# Text(0.5, 1.0, 'Probabilidad continua')

# %%
mead, var, sken, kurt = norm.stats(moments = 'mvsk')
mead
# Out:
# array(0.)

# %%
var
# Out:
# array(1.)

# %%
sken
# Out:
# array(0.)

# %%
kurt
# Out:
# array(0.)
