# %%
import scipy.stats
import numpy as np 
import pandas as pd 

import matplotlib.pyplot as plt 
import seaborn as sns 

# %matplotlib inline

# %%
df = pd.read_csv('bicicletas-compartidas.csv')
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %%
# Categoricas
y = df ['cuartil-ano'].apply(lambda x: 'cuartil-'+str(int(x)))

# %%
fig, ax =plt.subplots()
ax.bar(y.value_counts().index, y.value_counts())
ax.set_xlabel('Cuatiles del año')
ax.set_ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
fig, ax =plt.subplots()
ax.bar(y.value_counts().index, y.value_counts())
ax.set_xlabel('Cuatiles del año')
ax.set_ylabel('Frecuencia')
ax.patches[1].set_facecolor('red')
ax.patches[3].set_facecolor('yellow')

# %%
 fig, ax = plt.subplots()
 ax.pie(y.value_counts(), labels = y.value_counts().index)
 ax.set_title('diagrama de pie')
# Out:
# Text(0.5, 1.0, 'diagrama de pie')

# %%
yv = df['viento']

# %%
 fig, ax = plt.subplots()
 ax.hist(yv, bins = 30)
 ax.set_xlabel('Viento')
 ax.set_ylabel('Frecuencia')
 plt.axvline(np.mean(yv),c='r', linestyle ='--', label = 'Promedio')
 plt.axvline(np.mean(yv)+np.std(yv) ,c='k', linestyle ='--', label = '+ 1-Desviación')
 plt.axvline(np.mean(yv)-np.std(yv) ,c='y', linestyle ='--', label = '- 1-Desviación')
 ax.legend()

# %%
 fig, ax = plt.subplots()
 ax.hist(yv, bins = 30)
 ax.set_xlabel('Viento')
 ax.set_ylabel('Frecuencia')
 plt.axvline(np.mean(yv),c='r', linestyle ='--', label = 'Promedio')
 plt.axvline(np.mean(yv)+np.std(yv) ,c='k', linestyle ='--', label = '+ 1-Desviación')
 plt.axvline(np.mean(yv)-np.std(yv) ,c='y', linestyle ='--', label = '- 1-Desviación')
 ax.set_title('Histograma de la variable del viento')
 #ax.grid(color ='gray', linestyle='--',linewidt=0.5)
 ax.legend(loc='best')
 plt.show()
