# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
muestra = [50,33,16,5,5,1]

# %%
media = np.mean(muestra)
media
# Out:
# 18.333333333333332

# %%
len(muestra)
# Out:
# 6

# %%
mediana = np.median(muestra)
mediana
# Out:
# 10.5

# %%
ax = sns.distplot(muestra, bins=100, kde=False, color='g')
